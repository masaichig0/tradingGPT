# %% [markdown]
# # This notebook, I will work on followings:
# * It's like chat with data, I will work on chat with history price data
# * I get historical price data using YahooFinance, then process data.
#     * Add indicators to the price data.

# %%
from price_data import Data
symbol = "NVDA"
nvda = Data(symbol, 50)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
nvda_price_df = nvda.process_data_2()

# %%
nvda_price_df.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 6042 2023-04-11  277.239990  277.899994  271.260010  271.690002  271.690002
# 6043 2023-04-12  273.700012  274.679993  264.480011  264.950012  264.950012
# 6044 2023-04-13  267.339996  268.869995  263.290009  264.630005  264.630005
# 6045 2023-04-14  265.040009  268.829987  262.200012  267.579987  267.579987
# 6046 2023-04-17  265.649994  270.059998  264.329987  270.019989  270.019989
#
#           Volume    Change Direction          OBV   SMA/short    SMA/long  \
# 6042  31437800.0 -4.100006      DOWN  14224486900  272.637997  239.812799
# 6043  44625900.0 -6.739990      DOWN  14179861000  272.722998  241.279399
# 6044  35361500.0 -0.320007      DOWN  14144499500  272.201999  242.664599
# 6045  39505500.0  2.949982        UP  14184005000  271.576999  243.827599
# 6046  32147100.0  2.440002        UP  14216152100  270.801999  244.886199
#
#           MACD  Signal Line        RSI      SlowK      SlowD
# ...
