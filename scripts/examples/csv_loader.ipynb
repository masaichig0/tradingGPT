# %%
import pandas as pd

file_path = r"C:\Users\Masa\PycharmProjects\tradingGPT\Docs\CSV_files\nvda_data.csv"

# %%
df = pd.read_csv(file_path)

# %%
len(df)
# Out:
# 100

# %%
df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-11-18  159.660004  160.020004  151.199997  154.089996  154.024429
# 1   2022-11-21  151.470001  154.770004  150.800003  153.169998  153.104828
# 2   2022-11-22  153.279999  160.580002  151.220001  160.380005  160.311768
# 3   2022-11-23  160.979996  165.270004  160.479996  165.190002  165.119705
# 4   2022-11-25  163.179993  164.869995  161.720001  162.699997  162.630768
# ..         ...         ...         ...         ...         ...         ...
# 95  2023-04-10  268.230011  276.209991  266.690002  275.790009  275.790009
# 96  2023-04-11  277.239990  277.899994  271.260010  271.690002  271.690002
# 97  2023-04-12  273.700012  274.679993  264.480011  264.950012  264.950012
# 98  2023-04-13  267.339996  268.869995  263.290009  264.630005  264.630005
# 99  2023-04-14  265.040009  268.829987  262.200012  267.579987  267.579987
#
# ...

# %%
from langchain.document_loaders.csv_loader import CSVLoader
loader = CSVLoader(file_path=file_path, source_column="Adj Close")
data = loader.load()

# %%
data
# Out:
# [Document(page_content='Date: 2022-11-18\nOpen: 159.66000366210938\nHigh: 160.02000427246094\nLow: 151.1999969482422\nClose: 154.08999633789062\nAdj Close: 154.02442932128906\nVolume: 49207200.0\nChange: -2.6800079345703125\nDirection: DOWN\nOBV: 13270667200\nSMA/short: 154.71300048828124\nSMA/long: 132.8881997680664\nMACD: 6.857790211491221\nSignal Line: 6.812062004621419\nRSI: 58.8849064770285\nSlowK: 67.0295379516149\nSlowD: 76.8612347004303', metadata={'source': '154.02442932128906', 'row': 0}),
# ...

# %% [markdown]
# ## Plan to use CSVs:
# * Store csv in the folder by categorize the documents
# * store different namespace in pinecone
# * Go to the `index_vectorestore_index_creation.ipynb` to look at the code using pinecone.
